# %%
bible_pd_ov = {"kon":"con","pipol":"people", "bi":"by", "en":"im", "yu":"you","bikos":["cos", "because"], "kom":"come",
"mi":"me", "wi":"we", "yu":"you", "yor":"your", "si":"see","rish":"reach", "doz":["those", "dose"], "awa":"our","won":"wan","karry":"carry","komot":["comot", "come out"],"evritin":["everytin","everything","everyting"], "destroy":"distroy", "people,":"people", "koll":"call"}

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,7)

plt.bar(list(bible_pd_ov.keys()), bible_pd_ov.values(), color='g')
plt.gcf().autofmt_xdate()
plt.ylabel('Occurrence of Orthographic Variation')
#ax.set_xticks(rotation='vertical')
plt.title('Orthographic Variation Graph For Entire Pidgin Mono Data')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ef3249645f7d> in <module>()
#       5 plt.rcParams["figure.figsize"] = (10,7)
#       6
# ----> 7 plt.bar(list(bible_pd_ov.keys()), bible_pd_ov.values(), color='g')
#       8 plt.gcf().autofmt_xdate()
#       9 plt.ylabel('Occurrence of Orthographic Variation')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
mono_ov = {'kon': 27729, 'pipol': 9948, 'bi': 93089, 'en': 453024, 'yu': 9130, 'bikos': 4353, 'kom': 4338, 'mi': 118028, 'wi': 153008, 'yor': 3401, 'si': 235114, 'rish': 2431, 'doz': 1541, 'awa': 10257, 'won': 4008, 'karry': 1088, 'komot': 2357, 'evritin': 1450, 'destroy': 4681, 'people,': 421, 'koll': 1099}
# Out:
# dict_keys(['kon', 'pipol', 'bi', 'en', 'yu', 'bikos', 'kom', 'mi', 'wi', 'yor', 'si', 'rish', 'doz', 'awa', 'won', 'karry', 'komot', 'evritin', 'destroy', 'people,', 'koll'])
# dict_values([27729, 9948, 93089, 453024, 9130, 4353, 4338, 118028, 153008, 3401, 235114, 2431, 1541, 10257, 4008, 1088, 2357, 1450, 4681, 421, 1099])

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,7)

plt.bar(list(mono_ov.keys()), mono_ov.values(), color='g')
plt.gcf().autofmt_xdate()
plt.ylabel('Occurrence of Orthographic Variation')
#ax.set_xticks(rotation='vertical')
plt.title('Orthographic Variation Graph For Entire Pidgin Mono Data')
plt.xticks(rotation=90)
plt.show()

# %%
x = list(mono_ov.keys())
y = list(mono_ov.values())
plt.rcParams["figure.figsize"] = (15,10)

plt.barh(x, y, color='g')
plt.xlabel('Occurrence of Orthographic Variation')
#ax.set_xticks(rotation='vertical')
plt.title('Orthographic Variation Graph For Entire Pidgin Mono Data')
for index, value in enumerate(y):
    plt.text(value, index,
             str(value))
 
plt.show()

# %%
senti_ov = {'kon': 43, 'pipol': 1, 'bi': 1398, 'en': 5902, 'yu': 23, 'bikos': 0, 'kom': 8, 'mi': 1286, 'wi': 2278, 'yor': 25, 'si': 2005, 'rish': 4, 'doz': 5, 'awa': 174, 'won': 302, 'karry': 0, 'komot': 2, 'evritin': 0, 'destroy': 7, 'people,': 0, 'koll': 0}

# %%
plt.rcParams["figure.figsize"] = (10,5.5)

plt.bar(list(senti_ov.keys()), senti_ov.values(), color='b')
plt.gcf().autofmt_xdate()
plt.ylabel('Occurrence of Orthographic Variation')
#ax.set_xticks(rotation='vertical')
plt.title('Orthographic Variation Graph For Sentiment Analysis Data')
plt.xticks(rotation=90)
plt.show()

# %%
x = list(senti_ov.keys())
y = list(senti_ov.values())
plt.rcParams["figure.figsize"] = (15,10)

plt.barh(x, y, color='g')
plt.xlabel('Occurrence of Orthographic Variation')
#ax.set_xticks(rotation='vertical')
plt.title('Orthographic Variation Graph For Sentiment Analysis Data')
for index, value in enumerate(y):
    plt.text(value, index,
             str(value))
 
plt.show()
